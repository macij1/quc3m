# %%
import subprocess, os

# Si ya había un server previo, lo paramos
try:
    _doc_server.terminate()
except:
    pass

_doc_server = subprocess.Popen(
    ["python3", "-m", "http.server", "8500", "--directory", "dadk-documentation"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
)

print(f"✅ Servidor de documentación iniciado en http://localhost:8500 (PID {_doc_server.pid})")
# Out:
# ✅ Servidor de documentación iniciado en http://localhost:8500 (PID 533)

# %%
import os
from IPython.display import IFrame

base = os.environ.get("JUPYTERHUB_SERVICE_PREFIX", "")  
IFrame(f"{base}proxy/8500/", width="100%", height=800)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="/user/admin_qcentroid.xyz/proxy/8500/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
